# %%
import numpy as np
from torchvision import transforms
from torch.utils.data import DataLoader, TensorDataset
import os
import torch
import torchvision
import torchvision.datasets as datasets
import torch.nn as nn
import torch.nn.functional as F
from sklearn.preprocessing import StandardScaler, MinMaxScaler


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from torchvision.models import efficientnet_b3 as ENB3
from torchvision.models import efficientnet_v2_s as ENV2S
from torchvision.models import regnet_y_128gf as RNY128
from torchvision.models import regnet_y_16gf as RNY16

# %%
def generate_embeddings(embeddings_file_name):
    """
    Transform, resize and normalize the images and then use a pretrained model to extract 
    the embeddings.
    """
    # TODO: define a transform to pre-process the images
    # train_transforms = transforms.Compose(
    #     # maybe need to resize?
    #     # [transforms.Resize((224, 224)),]
    #     # maybe normalize?
    #     # [transforms.Normalize()]
    #     [transforms.ToTensor()])
    weights = torchvision.models.RegNet_Y_16GF_Weights.IMAGENET1K_SWAG_E2E_V1
    train_dataset = datasets.ImageFolder(root="./dataset/", transform=weights.transforms())
    # Hint: adjust batch_size and num_workers to your PC configuration, so that you don't 
    # run out of memory
    train_loader = DataLoader(dataset=train_dataset,
                              batch_size=1,
                              shuffle=False,
                              pin_memory=True, num_workers=6)

    # TODO: define a model for extraction of the embeddings (Hint: load a pretrained model,
    #  more info here: https://pytorch.org/vision/stable/models.html)
    # model = nn.Module()
    model = RNY16(weights=weights)
    embeddings = []
    embedding_size = model.fc.in_features  # Dummy variable, replace with the actual embedding size once you pick your model

    num_images = len(train_dataset)
    embeddings = np.zeros((num_images, embedding_size))
    # TODO: Use the model to extract the embeddings. Hint: remove the last layers of the 
    # model to access the embeddings the model generates.

    # remove last layer
    model = nn.Sequential(*list(model.children())[:-1])

    model.to(device)

    # extract embeddings
    for i, (images, _) in enumerate(train_loader):
        embeddings[i] = model(images.to(device)).flatten().cpu().detach().numpy()

    np.save(embeddings_file_name, embeddings)

# %%
embeddings_file_name = 'dataset/embeddings-RNY16.npy'
# generate embedding for each image in the dataset
if(os.path.exists(embeddings_file_name) == False):
    generate_embeddings(embeddings_file_name)
# Out:
# Downloading: "https://download.pytorch.org/models/regnet_y_16gf_swag-43afe44d.pth" to C:\Users\linan/.cache\torch\hub\checkpoints\regnet_y_16gf_swag-43afe44d.pth
# 100.0%

# %%
def get_data(file, train=True):
    """
    Load the triplets from the file and generate the features and labels.

    input: file: string, the path to the file containing the triplets
          train: boolean, whether the data is for training or testing

    output: X: numpy array, the features
            y: numpy array, the labels
    """
    triplets = []
    with open(file) as f:
        for line in f:
            triplets.append(line)

    # generate training data from triplets
    train_dataset = datasets.ImageFolder(root="dataset/",
                                         transform=None)
    filenames = [s[0].split('\\')[-1].replace('.jpg', '') for s in train_dataset.samples]
    embeddings = np.load(embeddings_file_name)
    # TODO: Normalize the embeddings across the dataset
    embeddings = StandardScaler().fit_transform(embeddings)

    file_to_embedding = {}
    for i in range(len(filenames)):
        file_to_embedding[filenames[i]] = embeddings[i]
    X = []
    y = []
    # use the individual embeddings to generate the features and labels for triplets
    for t in triplets:
        emb = [file_to_embedding[a] for a in t.split()]
        X.append(np.hstack([emb[0], emb[1], emb[2]]))
        y.append(1)
        # Generating negative samples (data augmentation)
        if train:
            X.append(np.hstack([emb[0], emb[2], emb[1]]))
            y.append(0)
    X = np.vstack(X)
    y = np.hstack(y)
    return X, y

# %%
TRAIN_TRIPLETS = 'train_triplets.txt'
TEST_TRIPLETS = 'test_triplets.txt'

# load the training and testing data
X, y = get_data(TRAIN_TRIPLETS)
X_test, _ = get_data(TEST_TRIPLETS, train=False)

# %%
X.shape[1]
# Out:
# 9072

# %%
# Hint: adjust batch_size and num_workers to your PC configuration, so that you don't run out of memory
def create_loader_from_np(X, y = None, train = True, batch_size=64, shuffle=True, num_workers = 4):
    """
    Create a torch.utils.data.DataLoader object from numpy arrays containing the data.

    input: X: numpy array, the features
           y: numpy array, the labels
    
    output: loader: torch.data.util.DataLoader, the object containing the data
    """
    if train:
        dataset = TensorDataset(torch.from_numpy(X).type(torch.float), 
                                torch.from_numpy(y).type(torch.long))
    else:
        dataset = TensorDataset(torch.from_numpy(X).type(torch.float))
    loader = DataLoader(dataset=dataset,
                        batch_size=batch_size,
                        shuffle=shuffle,
                        pin_memory=True, num_workers=num_workers)
    return loader

# %%
# Create data loaders for the training and testing data
train_loader = create_loader_from_np(X, y, train = True, batch_size=64)
test_loader = create_loader_from_np(X_test, train = False, batch_size=2048, shuffle=False)

# %%
def test_model(model, loader, filename='results.txt'):
    """
    The testing procedure of the model; it accepts the testing data and the trained model and 
    then tests the model on it.

    input: model: torch.nn.Module, the trained model
           loader: torch.data.util.DataLoader, the object containing the testing data
        
    output: None, the function saves the predictions to a results.txt file
    """
    model.eval()
    predictions = []
    # Iterate over the test data
    with torch.no_grad(): # We don't need to compute gradients for testing
        for [x_batch] in loader:
            x_batch= x_batch.to(device)
            predicted = model(x_batch)
            predicted = predicted.cpu().numpy()
            # Rounding the predictions to 0 or 1
            predicted[predicted >= 0.5] = 1
            predicted[predicted < 0.5] = 0
            predictions.append(predicted)
        predictions = np.vstack(predictions)
    np.savetxt(filename, predictions, fmt='%i')

# %%
# TODO: define a model. Here, the basic structure is defined, but you need to fill in the details
class Net(nn.Module):
    """
    The model class, which defines our classifier.
    """
    def __init__(self):
        """
        The constructor of the model.
        """
        super().__init__()
        self.fc1 = nn.Linear(X.shape[1], 4096)
        self.fc2 = nn.Linear(4096, 1024)
        self.fc3 = nn.Linear(1024, 512)
        self.fc4 = nn.Linear(512, 256)
        self.fc5 = nn.Linear(256, 16)
        self.fc6 = nn.Linear(16, 1)

    def forward(self, x):
        """
        The forward pass of the model.

        input: x: torch.Tensor, the input to the model

        output: x: torch.Tensor, the output of the model
        """
        x = F.relu(self.fc1(x))
        x = F.dropout(x, p=0.3)
        x = F.relu(self.fc2(x))
        x = F.dropout(x, p=0.4)
        x = F.relu(self.fc3(x))
        x = F.dropout(x, p=0.5)
        x = F.relu(self.fc4(x))
        x = F.dropout(x, p=0.5)
        x = F.relu(self.fc5(x))
        x = torch.sigmoid(self.fc6(x))
        return x

# %%
def train_model(train_loader):
    """
    The training procedure of the model; it accepts the training data, defines the model 
    and then trains it.

    input: train_loader: torch.data.util.DataLoader, the object containing the training data
    
    output: model: torch.nn.Module, the trained model
    """
    model = Net()
    model.train()
    model.to(device)
    n_epochs = 100
    # TODO: define a loss function, optimizer and proceed with training. Hint: use the part 
    # of the training data as a validation split. After each epoch, compute the loss on the 
    # validation split and print it out. This enables you to see how your model is performing 
    # on the validation data before submitting the results on the server. After choosing the 
    # best model, train it on the whole training data.
    loss_fun = nn.BCELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.3, patience=5, verbose=True)
    train_size = len(train_loader.dataset)
    valid_size = int(train_size * 0.1)
    train_size = train_size - valid_size
    epoch_train_data, epoch_valid_data = torch.utils.data.random_split(train_loader.dataset, [train_size, valid_size])
    epoch_train_loader = create_loader_from_np(epoch_train_data[:][0].numpy(), epoch_train_data[:][1].numpy(), train = True, batch_size=64)
    epoch_valid_loader = create_loader_from_np(epoch_valid_data[:][0].numpy(), epoch_valid_data[:][1].numpy(), train = True, batch_size=64)
    for epoch in range(n_epochs):
        train_loss = 0
        valid_loss = 0
        number_of_correct_train = 0
        number_of_correct_valid = 0
        for [x, t] in epoch_train_loader:
            optimizer.zero_grad()
            output = model(x.to(device)).flatten()
            prediction = (output >= 0.5).type(torch.int)
            t = t.to(device)
            number_of_correct_train += (prediction == t).sum().item()
            loss = loss_fun(output, t.type(torch.float))
            loss.backward()
            optimizer.step()
            train_loss += loss.item() 
        train_loss /= len(epoch_train_loader)
        with torch.no_grad():
            for [x, t] in epoch_valid_loader:
                output = model(x.to(device)).flatten()
                prediction = (output >= 0.5).type(torch.int)
                t = t.to(device)
                number_of_correct_valid += (prediction == t).sum().item()
                loss = loss_fun(output, t.to(device).type(torch.float))
                valid_loss += loss.item()
            valid_loss /= len(epoch_valid_loader)
        scheduler.step(number_of_correct_valid / valid_size)
        print('Epoch: {}, Training Loss: {:.4f}, Validation Loss: {:.4f}'.format(epoch+1, train_loss, valid_loss))
        print('Training Accuracy: {:.4f}, Validation Accuracy: {:.4f}'.format(number_of_correct_train / train_size, number_of_correct_valid / valid_size))
        if (optimizer.param_groups[0]['lr'] < 1e-6):
            break
    return model

# %%
# define a model and train it
model = train_model(train_loader)
# Out:
# Epoch: 1, Training Loss: 0.6837, Validation Loss: 0.6657
# Training Accuracy: 0.5499, Validation Accuracy: 0.5835
# Epoch: 2, Training Loss: 0.6436, Validation Loss: 0.6210
# Training Accuracy: 0.6208, Validation Accuracy: 0.6503
# Epoch: 3, Training Loss: 0.5847, Validation Loss: 0.5854
# Training Accuracy: 0.6867, Validation Accuracy: 0.6923
# Epoch: 4, Training Loss: 0.5290, Validation Loss: 0.5506
# Training Accuracy: 0.7347, Validation Accuracy: 0.7139
# Epoch: 5, Training Loss: 0.4798, Validation Loss: 0.5312
# Training Accuracy: 0.7690, Validation Accuracy: 0.7379
# Epoch: 6, Training Loss: 0.4348, Validation Loss: 0.5083
# Training Accuracy: 0.7970, Validation Accuracy: 0.7496
# Epoch: 7, Training Loss: 0.3927, Validation Loss: 0.4832
# Training Accuracy: 0.8243, Validation Accuracy: 0.7660
# Epoch: 8, Training Loss: 0.3601, Validation Loss: 0.4804
# Training Accuracy: 0.8422, Validation Accuracy: 0.7780
# Epoch: 9, Training Loss: 0.3291, Validation Loss: 0.5350
# Training Accuracy: 0.8594, Validation Accuracy: 0.7954
# Epoch: 10, Training Loss: 0.3072, Validation Loss: 0.4635
# Training Accuracy: 0.8712, Validation Accuracy: 0.8050
# Epoch: 11, Training Loss: 0.2868, Validation Loss: 0.4680
# Training Accuracy: 0.8816, Validation Accuracy: 0.8084
# Epoch: 12, Training Loss: 0.2722, Validation Loss: 0.4415
# Training Accuracy: 0.8891, Validation Accuracy: 0.8078
# Epoch: 13, Training Loss: 0.2652, Validation Loss: 0.4463
# Training Accuracy: 0.8920, Validation Accuracy: 0.8146
# Epoch: 14, Training Loss: 0.2532, Validation Loss: 0.4636
# Training Accuracy: 0.8980, Validation Accuracy: 0.8130
# Epoch: 15, Training Loss: 0.2444, Validation Loss: 0.4123
# Training Accuracy: 0.9016, Validation Accuracy: 0.8222
# Epoch: 16, Training Loss: 0.2396, Validation Loss: 0.4149
# Training Accuracy: 0.9048, Validation Accuracy: 0.8247
# Epoch: 17, Training Loss: 0.2344, Validation Loss: 0.4169
# Training Accuracy: 0.9059, Validation Accuracy: 0.8187
# Epoch: 18, Training Loss: 0.2289, Validation Loss: 0.4043
# Training Accuracy: 0.9101, Validation Accuracy: 0.8325
# Epoch: 19, Training Loss: 0.2272, Validation Loss: 0.4090
# Training Accuracy: 0.9099, Validation Accuracy: 0.8289
# Epoch: 20, Training Loss: 0.2229, Validation Loss: 0.4205
# Training Accuracy: 0.9118, Validation Accuracy: 0.8258
# Epoch: 21, Training Loss: 0.2215, Validation Loss: 0.4477
# Training Accuracy: 0.9143, Validation Accuracy: 0.8291
# Epoch: 22, Training Loss: 0.2167, Validation Loss: 0.4564
# Training Accuracy: 0.9149, Validation Accuracy: 0.8327
# Epoch: 23, Training Loss: 0.2161, Validation Loss: 0.4349
# Training Accuracy: 0.9164, Validation Accuracy: 0.8298
# Epoch: 24, Training Loss: 0.2159, Validation Loss: 0.4511
# Training Accuracy: 0.9159, Validation Accuracy: 0.8276
# Epoch: 25, Training Loss: 0.2132, Validation Loss: 0.4131
# Training Accuracy: 0.9169, Validation Accuracy: 0.8316
# Epoch: 26, Training Loss: 0.2138, Validation Loss: 0.4212
# Training Accuracy: 0.9169, Validation Accuracy: 0.8245
# Epoch: 27, Training Loss: 0.2126, Validation Loss: 0.4119
# Training Accuracy: 0.9173, Validation Accuracy: 0.8359
# Epoch: 28, Training Loss: 0.2109, Validation Loss: 0.4150
# Training Accuracy: 0.9174, Validation Accuracy: 0.8332
# Epoch: 29, Training Loss: 0.2093, Validation Loss: 0.4052
# Training Accuracy: 0.9185, Validation Accuracy: 0.8352
# Epoch: 30, Training Loss: 0.2088, Validation Loss: 0.4125
# Training Accuracy: 0.9190, Validation Accuracy: 0.8338
# Epoch: 31, Training Loss: 0.2077, Validation Loss: 0.4006
# Training Accuracy: 0.9187, Validation Accuracy: 0.8305
# Epoch: 32, Training Loss: 0.2048, Validation Loss: 0.3956
# Training Accuracy: 0.9214, Validation Accuracy: 0.8350
# Epoch: 33, Training Loss: 0.2071, Validation Loss: 0.3973
# Training Accuracy: 0.9188, Validation Accuracy: 0.8375
# Epoch: 34, Training Loss: 0.2044, Validation Loss: 0.4007
# Training Accuracy: 0.9204, Validation Accuracy: 0.8402
# Epoch: 35, Training Loss: 0.2041, Validation Loss: 0.3886
# Training Accuracy: 0.9202, Validation Accuracy: 0.8419
# Epoch: 36, Training Loss: 0.2045, Validation Loss: 0.4038
# Training Accuracy: 0.9211, Validation Accuracy: 0.8449
# Epoch: 37, Training Loss: 0.2037, Validation Loss: 0.4037
# Training Accuracy: 0.9209, Validation Accuracy: 0.8428
# Epoch: 38, Training Loss: 0.2037, Validation Loss: 0.4078
# Training Accuracy: 0.9223, Validation Accuracy: 0.8360
# Epoch: 39, Training Loss: 0.2027, Validation Loss: 0.4030
# Training Accuracy: 0.9218, Validation Accuracy: 0.8316
# Epoch: 40, Training Loss: 0.2008, Validation Loss: 0.4002
# Training Accuracy: 0.9220, Validation Accuracy: 0.8363
# Epoch: 41, Training Loss: 0.2020, Validation Loss: 0.3943
# Training Accuracy: 0.9221, Validation Accuracy: 0.8429
# Epoch: 42, Training Loss: 0.2018, Validation Loss: 0.3779
# Training Accuracy: 0.9225, Validation Accuracy: 0.8503
# Epoch: 43, Training Loss: 0.2042, Validation Loss: 0.3746
# Training Accuracy: 0.9217, Validation Accuracy: 0.8400
# Epoch: 44, Training Loss: 0.1984, Validation Loss: 0.3687
# Training Accuracy: 0.9236, Validation Accuracy: 0.8424
# Epoch: 45, Training Loss: 0.2002, Validation Loss: 0.4252
# Training Accuracy: 0.9225, Validation Accuracy: 0.8432
# Epoch: 46, Training Loss: 0.1997, Validation Loss: 0.3982
# Training Accuracy: 0.9220, Validation Accuracy: 0.8420
# Epoch: 47, Training Loss: 0.1978, Validation Loss: 0.4270
# Training Accuracy: 0.9222, Validation Accuracy: 0.8430
# Epoch 00048: reducing learning rate of group 0 to 3.0000e-04.
# Epoch: 48, Training Loss: 0.2013, Validation Loss: 0.3830
# Training Accuracy: 0.9224, Validation Accuracy: 0.8352
# Epoch: 49, Training Loss: 0.1170, Validation Loss: 0.4087
# Training Accuracy: 0.9570, Validation Accuracy: 0.8733
# Epoch: 50, Training Loss: 0.0828, Validation Loss: 0.3963
# Training Accuracy: 0.9709, Validation Accuracy: 0.8783
# Epoch: 51, Training Loss: 0.0731, Validation Loss: 0.3848
# Training Accuracy: 0.9732, Validation Accuracy: 0.8903
# Epoch: 52, Training Loss: 0.0702, Validation Loss: 0.3554
# Training Accuracy: 0.9753, Validation Accuracy: 0.8851
# Epoch: 53, Training Loss: 0.0662, Validation Loss: 0.3493
# Training Accuracy: 0.9764, Validation Accuracy: 0.8921
# Epoch: 54, Training Loss: 0.0647, Validation Loss: 0.3350
# Training Accuracy: 0.9770, Validation Accuracy: 0.8888
# Epoch: 55, Training Loss: 0.0613, Validation Loss: 0.3810
# Training Accuracy: 0.9784, Validation Accuracy: 0.8845
# Epoch: 56, Training Loss: 0.0643, Validation Loss: 0.3611
# Training Accuracy: 0.9773, Validation Accuracy: 0.8889
# Epoch: 57, Training Loss: 0.0603, Validation Loss: 0.3939
# Training Accuracy: 0.9787, Validation Accuracy: 0.8883
# Epoch: 58, Training Loss: 0.0619, Validation Loss: 0.3603
# Training Accuracy: 0.9777, Validation Accuracy: 0.8856
# Epoch: 59, Training Loss: 0.0633, Validation Loss: 0.3357
# Training Accuracy: 0.9780, Validation Accuracy: 0.8926
# Epoch: 60, Training Loss: 0.0641, Validation Loss: 0.3602
# Training Accuracy: 0.9771, Validation Accuracy: 0.8917
# Epoch: 61, Training Loss: 0.0649, Validation Loss: 0.3742
# Training Accuracy: 0.9777, Validation Accuracy: 0.8863
# Epoch: 62, Training Loss: 0.0624, Validation Loss: 0.3459
# Training Accuracy: 0.9779, Validation Accuracy: 0.8939
# Epoch: 63, Training Loss: 0.0636, Validation Loss: 0.3496
# Training Accuracy: 0.9771, Validation Accuracy: 0.8911
# Epoch: 64, Training Loss: 0.0631, Validation Loss: 0.3284
# Training Accuracy: 0.9778, Validation Accuracy: 0.8904
# Epoch: 65, Training Loss: 0.0618, Validation Loss: 0.3577
# Training Accuracy: 0.9778, Validation Accuracy: 0.8864
# Epoch: 66, Training Loss: 0.0656, Validation Loss: 0.3650
# Training Accuracy: 0.9768, Validation Accuracy: 0.8881
# Epoch: 67, Training Loss: 0.0639, Validation Loss: 0.3486
# Training Accuracy: 0.9773, Validation Accuracy: 0.8931
# Epoch: 68, Training Loss: 0.0619, Validation Loss: 0.3127
# Training Accuracy: 0.9783, Validation Accuracy: 0.8980
# Epoch: 69, Training Loss: 0.0642, Validation Loss: 0.3312
# Training Accuracy: 0.9773, Validation Accuracy: 0.8920
# Epoch: 70, Training Loss: 0.0631, Validation Loss: 0.4290
# Training Accuracy: 0.9779, Validation Accuracy: 0.8919
# Epoch: 71, Training Loss: 0.0651, Validation Loss: 0.3299
# Training Accuracy: 0.9770, Validation Accuracy: 0.8919
# Epoch: 72, Training Loss: 0.0652, Validation Loss: 0.3275
# Training Accuracy: 0.9772, Validation Accuracy: 0.8905
# Epoch: 73, Training Loss: 0.0678, Validation Loss: 0.3637
# Training Accuracy: 0.9759, Validation Accuracy: 0.8894
# Epoch 00074: reducing learning rate of group 0 to 9.0000e-05.
# Epoch: 74, Training Loss: 0.0658, Validation Loss: 0.3973
# Training Accuracy: 0.9765, Validation Accuracy: 0.8796
# Epoch: 75, Training Loss: 0.0433, Validation Loss: 0.3490
# Training Accuracy: 0.9851, Validation Accuracy: 0.8990
# Epoch: 76, Training Loss: 0.0340, Validation Loss: 0.3731
# Training Accuracy: 0.9888, Validation Accuracy: 0.9026
# Epoch: 77, Training Loss: 0.0296, Validation Loss: 0.3791
# Training Accuracy: 0.9897, Validation Accuracy: 0.9043
# Epoch: 78, Training Loss: 0.0269, Validation Loss: 0.3456
# Training Accuracy: 0.9907, Validation Accuracy: 0.9061
# Epoch: 79, Training Loss: 0.0259, Validation Loss: 0.3777
# Training Accuracy: 0.9915, Validation Accuracy: 0.9073
# Epoch: 80, Training Loss: 0.0245, Validation Loss: 0.3404
# Training Accuracy: 0.9918, Validation Accuracy: 0.9109
# Epoch: 81, Training Loss: 0.0234, Validation Loss: 0.4050
# Training Accuracy: 0.9921, Validation Accuracy: 0.9104
# Epoch: 82, Training Loss: 0.0216, Validation Loss: 0.3666
# Training Accuracy: 0.9928, Validation Accuracy: 0.9110
# Epoch: 83, Training Loss: 0.0232, Validation Loss: 0.3735
# Training Accuracy: 0.9921, Validation Accuracy: 0.9132
# Epoch: 84, Training Loss: 0.0214, Validation Loss: 0.3289
# Training Accuracy: 0.9928, Validation Accuracy: 0.9171
# Epoch: 85, Training Loss: 0.0207, Validation Loss: 0.3354
# Training Accuracy: 0.9930, Validation Accuracy: 0.9142
# Epoch: 86, Training Loss: 0.0211, Validation Loss: 0.3944
# Training Accuracy: 0.9928, Validation Accuracy: 0.9114
# Epoch: 87, Training Loss: 0.0214, Validation Loss: 0.3389
# Training Accuracy: 0.9929, Validation Accuracy: 0.9176
# Epoch: 88, Training Loss: 0.0208, Validation Loss: 0.3574
# Training Accuracy: 0.9930, Validation Accuracy: 0.9117
# Epoch: 89, Training Loss: 0.0189, Validation Loss: 0.3420
# Training Accuracy: 0.9934, Validation Accuracy: 0.9172
# Epoch: 90, Training Loss: 0.0200, Validation Loss: 0.3548
# Training Accuracy: 0.9934, Validation Accuracy: 0.9093
# Epoch: 91, Training Loss: 0.0198, Validation Loss: 0.3562
# Training Accuracy: 0.9932, Validation Accuracy: 0.9154
# Epoch: 92, Training Loss: 0.0193, Validation Loss: 0.3587
# Training Accuracy: 0.9934, Validation Accuracy: 0.9150
# Epoch 00093: reducing learning rate of group 0 to 2.7000e-05.
# Epoch: 93, Training Loss: 0.0195, Validation Loss: 0.3617
# Training Accuracy: 0.9933, Validation Accuracy: 0.9128
# Epoch: 94, Training Loss: 0.0178, Validation Loss: 0.3913
# Training Accuracy: 0.9943, Validation Accuracy: 0.9143
# Epoch: 95, Training Loss: 0.0142, Validation Loss: 0.3909
# Training Accuracy: 0.9951, Validation Accuracy: 0.9206
# Epoch: 96, Training Loss: 0.0141, Validation Loss: 0.3594
# Training Accuracy: 0.9952, Validation Accuracy: 0.9190
# Epoch: 97, Training Loss: 0.0126, Validation Loss: 0.4363
# Training Accuracy: 0.9959, Validation Accuracy: 0.9186
# Epoch: 98, Training Loss: 0.0122, Validation Loss: 0.3748
# Training Accuracy: 0.9961, Validation Accuracy: 0.9194
# Epoch: 99, Training Loss: 0.0122, Validation Loss: 0.3871
# Training Accuracy: 0.9961, Validation Accuracy: 0.9204
# Epoch: 100, Training Loss: 0.0115, Validation Loss: 0.3861
# Training Accuracy: 0.9961, Validation Accuracy: 0.9228

# %%
# test the model on the test data
filename = 'results-RNY16-6layers.txt'
test_model(model, test_loader, filename)
print("Results saved to", filename)
# Out:
# Results saved to results-RNY16-6layers.txt
